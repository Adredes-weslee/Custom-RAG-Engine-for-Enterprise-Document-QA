# %%
import gitlab
import os
import time
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get the private token from environment variables
PRIVATE_TOKEN = os.getenv("PRIVATE_TOKEN")
if not PRIVATE_TOKEN:
    raise ValueError("PRIVATE_TOKEN is not set. Please set it in the .env file.")

# Authenticate with your GitLab instance
GITLAB_URL = "https://gitlab.aisingapore.net"

# Initialize GitLab connection
gl = gitlab.Gitlab(GITLAB_URL, private_token=PRIVATE_TOKEN)

# Access the project by its ID
project_id = 2529  # Replace with your actual project ID
aiap_project = gl.projects.get(project_id)

# Directory to store the downloaded files
BASE_DOWNLOAD_DIR = "aiap17-gitlab-data"
os.makedirs(BASE_DOWNLOAD_DIR, exist_ok=True)

# File extensions that are suitable for RAG LLM
RAG_FILE_EXTENSIONS = [
    ".md",
    ".txt",
    ".csv",
    ".json",
    ".yaml",
    ".yml",
    ".html",  # Textual formats
    ".py",
    ".ipynb",  # Python scripts and notebooks
    ".pdf",  # PDF files
]

# Branches to exclude
EXCLUDED_BRANCHES = [
    "15-research-open-source-models-or-cheaper-api-that-has-better-or-equal-performance-to-gpt-4o-mini",
    "4-review-literature-on-vision-transformer-models",
    "master",
    "main",
    "new_joey",
    "feature-add-new-test-cases",
    "pei_shan_n",
]


# Function to determine if a file is suitable for RAG based on its extension
def is_rag_file(file_path):
    _, ext = os.path.splitext(file_path)
    return ext.lower() in RAG_FILE_EXTENSIONS


# Function to scrape all files in a specific branch
def scrape_branch(branch_name):
    # Get repository tree (files and directories) at the root level of the branch
    tree = aiap_project.repository_tree(ref=branch_name, recursive=True, get_all=True)

    for item in tree:
        # File path to be saved inside the base directory aiap17-gitlab-data
        item_path = os.path.join(BASE_DOWNLOAD_DIR, branch_name, item["path"])

        if item["type"] == "blob" and is_rag_file(
            item["path"]
        ):  # If it's a suitable file
            # Create directories as needed
            os.makedirs(os.path.dirname(item_path), exist_ok=True)

            # Extract the file extension
            _, ext = os.path.splitext(item["path"])

            # Implementing retry mechanism
            max_retries = 3
            for attempt in range(max_retries):
                try:
                    # Get file content from the GitLab API
                    file_data = aiap_project.files.get(
                        file_path=item["path"], ref=branch_name
                    )
                    file_content = file_data.decode()

                    # Write file content (handle both text and binary-like files properly)
                    if ext.lower() in [
                        ".py",
                        ".md",
                        ".txt",
                        ".yaml",
                        ".yml",
                        ".html",
                        ".csv",
                        ".json",
                    ]:
                        # Handle text file
                        file_content_text = file_content.decode("utf-8")
                        with open(item_path, "w", encoding="utf-8") as f:
                            f.write(file_content_text)
                        print(
                            f"Downloaded text file: {item['path']} from branch: {branch_name}"
                        )
                    else:
                        # Handle binary-like file (e.g., Jupyter notebooks, PDFs)
                        with open(item_path, "wb") as f:
                            f.write(file_content)
                        print(
                            f"Downloaded binary-like file: {item['path']} from branch: {branch_name}"
                        )

                    # Break if successful
                    break

                except gitlab.exceptions.GitlabGetError as e:
                    print(
                        f"Attempt {attempt + 1} to download file {item['path']} failed. Error: {e}"
                    )
                    if attempt < max_retries - 1:
                        time.sleep(5)  # Wait for 5 seconds before retrying
                    else:
                        print(
                            f"Failed to download file {item['path']} after {max_retries} attempts."
                        )

        elif item["type"] == "tree":  # If it's a directory
            # Create directory
            os.makedirs(item_path, exist_ok=True)
            print(f"Directory found: {item['path']}")


# Function to scrape all branches of a project, excluding specified branches
def scrape_all_branches():
    # Get all branches of the project
    branches = aiap_project.branches.list(all=True)

    for branch in branches:
        branch_name = branch.name
        if branch_name not in EXCLUDED_BRANCHES:
            print(f"Scraping branch: {branch_name}")
            scrape_branch(branch_name)
            print(f"Scraping complete for branch: {branch_name}")
        else:
            print(f"Skipping branch: {branch_name} (excluded)")


# Scrape all branches
scrape_all_branches()
print("Scraping complete for all branches.")
# Out:
# Skipping branch: 15-research-open-source-models-or-cheaper-api-that-has-better-or-equal-performance-to-gpt-4o-mini (excluded)
# Skipping branch: 4-review-literature-on-vision-transformer-models (excluded)
# Scraping branch: Onn_Yun_Hui
# Directory found: assignment0
# Directory found: assignment1
# Directory found: assignment1/src
# Directory found: assignment1/tests
# Directory found: assignment2
# Directory found: assignment2/A2P1_docker_workshop
# Directory found: assignment2/A2P1_docker_workshop/assets
# Directory found: assignment2/imgs
# Directory found: assignment3
# Directory found: assignment4
# Directory found: assignment4/src
# Directory found: assignment4/tests
# Directory found: assignment5
# Directory found: assignment5/data
# Directory found: assignment5/data/image
# Directory found: assignment5/images
# Directory found: assignment5/robustness_requirements
# Directory found: assignment5/src
# Directory found: assignment5/tests
# Directory found: assignment6
# Directory found: assignment6/images
# Directory found: assignment6/src
# Directory found: assignment6/tests
# Directory found: assignment7
# Directory found: assignment7/images
# Directory found: assignment7/src
# Directory found: assignment7/tests
# Directory found: assignment8
# Directory found: assignment8/data
# Directory found: ci
# Directory found: imgs
# Downloaded text file: .gitlab-ci.yml from branch: Onn_Yun_Hui
# Downloaded text file: README.md from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment0/A0P2_virenv_commit.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment0/README.md from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment1/A1P1_eda_extended.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment1/A1P2_intro_supervised.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment1/A1P3_rf_from_scratch.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/README.md from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/SWEETVIZ_REPORT.html from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/conda.yml from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/config.yaml from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/src/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/src/datapipeline.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/src/decision_tree.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/src/model.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/src/random_forest.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/src/random_forest_1.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/src/random_forest_2.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/tests/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment1/tests/test_model.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment2/A2P1_docker_workshop/app.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment2/A2P1_docker_workshop/hello.txt from branch: Onn_Yun_Hui
# Downloaded text file: assignment2/A2P1_docker_workshop/requirements.txt from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment2/A2_docker_overview.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment2/README.md from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/A3P1_load_data.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/A3P2_eda.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/A3P3_data_cleaning.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/A3P4_model_training.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/A3P5_exercise.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment3/README.md from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/kapitan-spark-slides.pdf from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/slides-day1.pdf from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment3/slides-day2.pdf from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment4/A4P3_neural_network_scratch.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/README.md from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/requirements.txt from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/src/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/src/datapipeline.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/src/mlp.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/src/mlp_datapipeline.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/tests/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment4/tests/test_mlp.py from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment5/A5P1_introduction.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment5/A5P2_classification.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment5/A5P3_buildCNN.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu_AppleSilicon.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment5/A5P5_robustness_testing.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/README.md from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/conda.yml from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/requirements.txt from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/requirements_m1.txt from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness.txt from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness_cuda.txt from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/src/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/src/convolved_matrices.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/src/train.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/tests/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment5/tests/test_convolved_matrices.py from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment6/A6P1_eda_data_cleaning.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment6/A6P2_time_series_forecasting.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment6/A6P3_time_series_nn.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/README.md from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/conda.yml from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/src/cnn_model.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/src/datapipeline.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/src/ml_experiment.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/src/ml_model.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/src/rnn_model.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/src/windowing.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment6/tests/__init__.py from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment7/A7P1_nlp_introduction.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment7/A7P2_nlp_attention.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment7/A7P3_nlp_transformer.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment7/README.md from branch: Onn_Yun_Hui
# Downloaded text file: assignment7/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment7/conda.yml from branch: Onn_Yun_Hui
# Downloaded text file: assignment7/src/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment7/src/context_vector.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment7/tests/__init__.py from branch: Onn_Yun_Hui
# Downloaded text file: assignment7/tests/test_context_vector.py from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment8/A8P1_llm_introduction.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment8/A8P2_prompt_engineering.ipynb from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment8/A8P3_retrieval-augmented_generation.ipynb from branch: Onn_Yun_Hui
# Downloaded text file: assignment8/README.md from branch: Onn_Yun_Hui
# Downloaded text file: assignment8/__init__.py from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment8/data/AIAP_Batch 13_Technical_Assessment.pdf from branch: Onn_Yun_Hui
# Downloaded binary-like file: assignment8/data/AIAP_Batch 14_Technical_Assessment.pdf from branch: Onn_Yun_Hui
# Downloaded text file: assignment8/data/AIAP_Batch_13_Technical_Assessment_Results.csv from branch: Onn_Yun_Hui
# Downloaded text file: assignment8/data/AIAP_Batch_14_Technical_Assessment_Results.csv from branch: Onn_Yun_Hui
# Scraping complete for branch: Onn_Yun_Hui
# Scraping branch: YorkYong
# Directory found: assignment0
# Directory found: assignment1
# Directory found: assignment1/src
# Directory found: assignment1/tests
# Directory found: assignment2
# Directory found: assignment2/A2P1_docker_workshop
# Directory found: assignment2/imgs
# Directory found: assignment3
# Directory found: assignment4
# Directory found: assignment4/AutoViz_Plots
# Directory found: assignment4/AutoViz_Plots/Class
# Directory found: assignment4/docker
# Directory found: assignment4/src
# Directory found: assignment4/tests
# Directory found: assignment5
# Directory found: assignment5/data
# Directory found: assignment5/data/image
# Directory found: assignment5/docker
# Directory found: assignment5/images
# Directory found: assignment5/mlruns
# Directory found: assignment5/mlruns/0
# Directory found: assignment5/robustness_requirements
# Directory found: assignment5/src
# Directory found: assignment5/tests
# Directory found: assignment6
# Directory found: assignment6/images
# Directory found: assignment6/src
# Directory found: assignment6/tests
# Directory found: assignment7
# Directory found: assignment7/images
# Directory found: assignment7/src
# Directory found: assignment7/tests
# Directory found: assignment8
# Directory found: assignment8/data
# Directory found: assignment8/image
# Directory found: assignment9
# Directory found: assignment9/notebook
# Directory found: ci
# Directory found: imgs
# Downloaded text file: .gitlab-ci.yml from branch: YorkYong
# Downloaded text file: README.md from branch: YorkYong
# Downloaded binary-like file: assignment0/A0P2_virenv_commit.ipynb from branch: YorkYong
# Downloaded text file: assignment0/README.md from branch: YorkYong
# Downloaded binary-like file: assignment1/A1P1_eda_extended.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment1/A1P2_intro_supervised.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment1/A1P3_rf_from_scratch.ipynb from branch: YorkYong
# Downloaded text file: assignment1/README.md from branch: YorkYong
# Downloaded text file: assignment1/__init__.py from branch: YorkYong
# Downloaded text file: assignment1/conda.yml from branch: YorkYong
# Downloaded text file: assignment1/report.html from branch: YorkYong
# Downloaded text file: assignment1/sample_report.html from branch: YorkYong
# Downloaded text file: assignment1/src/__init__.py from branch: YorkYong
# Downloaded text file: assignment1/src/datapipeline.py from branch: YorkYong
# Downloaded text file: assignment1/src/datapipeline_V1.py from branch: YorkYong
# Downloaded text file: assignment1/src/decision_tree.py from branch: YorkYong
# Downloaded text file: assignment1/src/model.py from branch: YorkYong
# Downloaded text file: assignment1/src/random_forest.py from branch: YorkYong
# Downloaded text file: assignment1/tests/__init__.py from branch: YorkYong
# Downloaded text file: assignment1/tests/test_model.py from branch: YorkYong
# Downloaded text file: assignment2/A2P1_docker_workshop/app.py from branch: YorkYong
# Downloaded text file: assignment2/A2P1_docker_workshop/hello.txt from branch: YorkYong
# Downloaded text file: assignment2/A2P1_docker_workshop/requirements.txt from branch: YorkYong
# Downloaded binary-like file: assignment2/A2_docker_overview.ipynb from branch: YorkYong
# Downloaded text file: assignment2/README.md from branch: YorkYong
# Downloaded text file: assignment2/Steps to Batch-inference on RunAI.txt from branch: YorkYong
# Downloaded text file: assignment2/Steps to Serve-API on docker.txt from branch: YorkYong
# Downloaded text file: assignment2/Steps to containerise the App.txt from branch: YorkYong
# Downloaded binary-like file: assignment3/A3P1_load_data.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment3/A3P2_eda.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment3/A3P3_data_cleaning.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment3/A3P4_model_training.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment3/A3P5_exercise.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: YorkYong
# Downloaded text file: assignment3/README.md from branch: YorkYong
# Downloaded binary-like file: assignment3/kapitan-spark-slides.pdf from branch: YorkYong
# Downloaded binary-like file: assignment3/slides-day1.pdf from branch: YorkYong
# Downloaded binary-like file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: YorkYong
# Downloaded binary-like file: assignment3/slides-day2.pdf from branch: YorkYong
# Downloaded binary-like file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment4/A4P3_neural_network_scratch.ipynb from branch: YorkYong
# Downloaded text file: assignment4/AutoViz_Plots/Class/distplots_nums.html from branch: YorkYong
# Downloaded text file: assignment4/AutoViz_Plots/Class/heatmaps.html from branch: YorkYong
# Downloaded text file: assignment4/AutoViz_Plots/Class/pair_scatters.html from branch: YorkYong
# Downloaded text file: assignment4/AutoViz_Plots/Class/scatterplots.html from branch: YorkYong
# Downloaded text file: assignment4/AutoViz_Plots/Class/violinplots.html from branch: YorkYong
# Downloaded text file: assignment4/README.md from branch: YorkYong
# Downloaded text file: assignment4/__init__.py from branch: YorkYong
# Downloaded text file: assignment4/conda-env.yaml from branch: YorkYong
# Downloaded text file: assignment4/conda.yml from branch: YorkYong
# Downloaded text file: assignment4/requirements.txt from branch: YorkYong
# Downloaded text file: assignment4/src/__init__.py from branch: YorkYong
# Downloaded text file: assignment4/src/datapipeline.py from branch: YorkYong
# Downloaded text file: assignment4/src/main.py from branch: YorkYong
# Downloaded text file: assignment4/src/mlp.py from branch: YorkYong
# Downloaded text file: assignment4/src/mlp_datapipeline.py from branch: YorkYong
# Downloaded text file: assignment4/src/pytorch_A4P2.py from branch: YorkYong
# Downloaded text file: assignment4/src/resampling.py from branch: YorkYong
# Downloaded text file: assignment4/src/train_A4P1.py from branch: YorkYong
# Downloaded text file: assignment4/src/train_A4P1_SwiGLU.py from branch: YorkYong
# Downloaded text file: assignment4/src/train_batchnorm.py from branch: YorkYong
# Downloaded text file: assignment4/src/train_leakyrelu.py from branch: YorkYong
# Downloaded text file: assignment4/src/tw_training.py from branch: YorkYong
# Downloaded text file: assignment4/src/utils.py from branch: YorkYong
# Downloaded text file: assignment4/tests/__init__.py from branch: YorkYong
# Downloaded text file: assignment4/tests/test_mlp.py from branch: YorkYong
# Downloaded binary-like file: assignment5/A5P1_introduction.ipynb from branch: YorkYong
# Downloaded text file: assignment5/A5P2_EDA_insights.txt from branch: YorkYong
# Downloaded binary-like file: assignment5/A5P2_classification.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment5/A5P3_buildCNN.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu_AppleSilicon.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment5/A5P5_robustness_testing.ipynb from branch: YorkYong
# Downloaded text file: assignment5/README.md from branch: YorkYong
# Downloaded text file: assignment5/__init__.py from branch: YorkYong
# Downloaded text file: assignment5/conda.yml from branch: YorkYong
# Downloaded text file: assignment5/mlruns/0/meta.yaml from branch: YorkYong
# Downloaded text file: assignment5/requirements.txt from branch: YorkYong
# Downloaded text file: assignment5/requirements_m1.txt from branch: YorkYong
# Downloaded text file: assignment5/requirements_nb.txt from branch: YorkYong
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness.txt from branch: YorkYong
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness_cuda.txt from branch: YorkYong
# Downloaded text file: assignment5/src/__init__.py from branch: YorkYong
# Downloaded text file: assignment5/src/convolved_matrices.py from branch: YorkYong
# Downloaded text file: assignment5/src/data_preparation.py from branch: YorkYong
# Downloaded text file: assignment5/src/data_preparation_new.py from branch: YorkYong
# Downloaded text file: assignment5/src/main.py from branch: YorkYong
# Downloaded text file: assignment5/src/main_new.py from branch: YorkYong
# Downloaded text file: assignment5/src/model_builder.py from branch: YorkYong
# Downloaded text file: assignment5/src/model_trainer.py from branch: YorkYong
# Downloaded text file: assignment5/src/train.py from branch: YorkYong
# Downloaded text file: assignment5/tests/__init__.py from branch: YorkYong
# Downloaded text file: assignment5/tests/test_convolved_matrices.py from branch: YorkYong
# Downloaded binary-like file: assignment6/A6P1_eda_data_cleaning.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment6/A6P2_time_series_forecasting.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment6/A6P2_time_series_forecasting_WS.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment6/A6P3_time_series_nn.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment6/ApprenticeSpotlight.ipynb from branch: YorkYong
# Downloaded text file: assignment6/README.md from branch: YorkYong
# Downloaded text file: assignment6/conda.yml from branch: YorkYong
# Downloaded text file: assignment6/requirements.txt from branch: YorkYong
# Downloaded text file: assignment6/src/cnn2d_model.py from branch: YorkYong
# Downloaded text file: assignment6/src/cnn_model.py from branch: YorkYong
# Downloaded text file: assignment6/src/datapipeline.py from branch: YorkYong
# Downloaded text file: assignment6/src/ml_experiment.py from branch: YorkYong
# Downloaded text file: assignment6/src/ml_model.py from branch: YorkYong
# Downloaded text file: assignment6/src/rnn_model.py from branch: YorkYong
# Downloaded text file: assignment6/src/windowing.py from branch: YorkYong
# Downloaded text file: assignment6/tests/__init__.py from branch: YorkYong
# Downloaded text file: assignment6/tests/test_pass.py from branch: YorkYong
# Downloaded binary-like file: assignment7/A7P1_nlp_introduction.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment7/A7P2_nlp_attention.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment7/A7P3_nlp_transformer.ipynb from branch: YorkYong
# Downloaded text file: assignment7/README.md from branch: YorkYong
# Downloaded text file: assignment7/__init__.py from branch: YorkYong
# Downloaded text file: assignment7/conda.yml from branch: YorkYong
# Downloaded text file: assignment7/requirements.txt from branch: YorkYong
# Downloaded text file: assignment7/src/__init__.py from branch: YorkYong
# Downloaded text file: assignment7/src/context_vector.py from branch: YorkYong
# Downloaded text file: assignment7/tests/__init__.py from branch: YorkYong
# Downloaded text file: assignment7/tests/test_context_vector.py from branch: YorkYong
# Downloaded binary-like file: assignment8/A8P1_llm_introduction.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment8/A8P2_prompt_engineering.ipynb from branch: YorkYong
# Downloaded binary-like file: assignment8/A8P3_retrieval-augmented_generation.ipynb from branch: YorkYong
# Downloaded text file: assignment8/README.md from branch: YorkYong
# Downloaded text file: assignment8/__init__.py from branch: YorkYong
# Downloaded text file: assignment8/app.py from branch: YorkYong
# Downloaded text file: assignment8/app_v2.py from branch: YorkYong
# Downloaded binary-like file: assignment8/data/AIAP_Batch 13_Technical_Assessment.pdf from branch: YorkYong
# Downloaded binary-like file: assignment8/data/AIAP_Batch 14_Technical_Assessment.pdf from branch: YorkYong
# Downloaded text file: assignment8/data/AIAP_Batch_13_Technical_Assessment_Results.csv from branch: YorkYong
# Downloaded text file: assignment8/data/AIAP_Batch_14_Technical_Assessment_Results.csv from branch: YorkYong
# Downloaded text file: assignment8/requirements.txt from branch: YorkYong
# Downloaded binary-like file: assignment9/notebook/model_testing.ipynb from branch: YorkYong
# Downloaded text file: assignment9/requirements.txt from branch: YorkYong
# Scraping complete for branch: YorkYong
# Scraping branch: chan_guan_ling
# Directory found: assignment0
# Directory found: assignment1
# Directory found: assignment1/src
# Directory found: assignment1/tests
# Directory found: assignment2
# Directory found: assignment2/A2P1_docker_workshop
# Directory found: assignment2/imgs
# Directory found: assignment3
# Directory found: assignment4
# Directory found: assignment4/src
# Directory found: assignment4/tests
# Directory found: assignment5
# Directory found: assignment5/data
# Directory found: assignment5/data/image
# Directory found: assignment5/images
# Directory found: assignment5/robustness_requirements
# Directory found: assignment5/src
# Directory found: assignment5/tests
# Directory found: assignment6
# Directory found: assignment6/images
# Directory found: assignment6/src
# Directory found: assignment6/tests
# Directory found: assignment7
# Directory found: assignment7/images
# Directory found: assignment7/src
# Directory found: assignment7/tests
# Directory found: assignment8
# Directory found: assignment8/data
# Directory found: ci
# Directory found: imgs
# Downloaded text file: .gitlab-ci.yml from branch: chan_guan_ling
# Downloaded text file: README.md from branch: chan_guan_ling
# Downloaded binary-like file: assignment0/A0P2_virenv_commit.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment0/README.md from branch: chan_guan_ling
# Downloaded binary-like file: assignment1/A1P1_eda_extended.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment1/A1P2_intro_supervised.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment1/A1P3_rf_from_scratch.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment1/README.md from branch: chan_guan_ling
# Downloaded text file: assignment1/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment1/src/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment1/src/datapipeline.py from branch: chan_guan_ling
# Downloaded text file: assignment1/src/decision_tree.py from branch: chan_guan_ling
# Downloaded text file: assignment1/src/model.py from branch: chan_guan_ling
# Downloaded text file: assignment1/tests/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment1/tests/test_model.py from branch: chan_guan_ling
# Downloaded text file: assignment2/A2P1_docker_workshop/app.py from branch: chan_guan_ling
# Downloaded text file: assignment2/A2P1_docker_workshop/hello.txt from branch: chan_guan_ling
# Downloaded text file: assignment2/A2P1_docker_workshop/requirements.txt from branch: chan_guan_ling
# Downloaded binary-like file: assignment2/A2_docker_overview.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment2/README.md from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/A3P1_load_data.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/A3P2_eda.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/A3P3_data_cleaning.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/A3P4_model_training.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/A3P5_exercise.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment3/README.md from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/kapitan-spark-slides.pdf from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/slides-day1.pdf from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: chan_guan_ling
# Downloaded binary-like file: assignment3/slides-day2.pdf from branch: chan_guan_ling
# Downloaded binary-like file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment4/A4P3_neural_network_scratch.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment4/README.md from branch: chan_guan_ling
# Downloaded text file: assignment4/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment4/src/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment4/src/a4p1_preprocess.py from branch: chan_guan_ling
# Downloaded text file: assignment4/src/a4p1_train_model.py from branch: chan_guan_ling
# Downloaded text file: assignment4/src/datapipeline.py from branch: chan_guan_ling
# Downloaded text file: assignment4/src/mlp.py from branch: chan_guan_ling
# Downloaded text file: assignment4/src/mlp_datapipeline.py from branch: chan_guan_ling
# Downloaded text file: assignment4/tests/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment4/tests/test_mlp.py from branch: chan_guan_ling
# Downloaded binary-like file: assignment5/A5P1_introduction.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment5/A5P2_classification.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment5/A5P3_buildCNN.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu_AppleSilicon.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment5/A5P5_robustness_testing.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment5/Convultion matrices - Google Sheets.pdf from branch: chan_guan_ling
# Downloaded text file: assignment5/README.md from branch: chan_guan_ling
# Downloaded text file: assignment5/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment5/requirements.txt from branch: chan_guan_ling
# Downloaded text file: assignment5/requirements_m1.txt from branch: chan_guan_ling
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness.txt from branch: chan_guan_ling
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness_cuda.txt from branch: chan_guan_ling
# Downloaded text file: assignment5/src/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment5/src/convolved_matrices.py from branch: chan_guan_ling
# Downloaded text file: assignment5/src/train.py from branch: chan_guan_ling
# Downloaded text file: assignment5/tests/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment5/tests/test_convolved_matrices.py from branch: chan_guan_ling
# Downloaded binary-like file: assignment6/A6P1_eda_data_cleaning.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment6/A6P2_time_series_forecasting.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment6/A6P3_time_series_nn.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment6/README.md from branch: chan_guan_ling
# Downloaded text file: assignment6/src/cnn_model.py from branch: chan_guan_ling
# Downloaded text file: assignment6/src/datapipeline.py from branch: chan_guan_ling
# Downloaded text file: assignment6/src/ml_experiment.py from branch: chan_guan_ling
# Downloaded text file: assignment6/src/ml_model.py from branch: chan_guan_ling
# Downloaded text file: assignment6/src/rnn_model.py from branch: chan_guan_ling
# Downloaded text file: assignment6/src/windowing.py from branch: chan_guan_ling
# Downloaded text file: assignment6/tests/__init__.py from branch: chan_guan_ling
# Downloaded binary-like file: assignment7/A7P1_nlp_introduction.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment7/A7P2_nlp_attention.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment7/A7P3_nlp_transformer.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment7/README.md from branch: chan_guan_ling
# Downloaded text file: assignment7/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment7/src/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment7/src/context_vector.py from branch: chan_guan_ling
# Downloaded text file: assignment7/tests/__init__.py from branch: chan_guan_ling
# Downloaded text file: assignment7/tests/test_context_vector.py from branch: chan_guan_ling
# Downloaded binary-like file: assignment8/A8P1_llm_introduction.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment8/A8P2_prompt_engineering.ipynb from branch: chan_guan_ling
# Downloaded binary-like file: assignment8/A8P3_retrieval-augmented_generation.ipynb from branch: chan_guan_ling
# Downloaded text file: assignment8/README.md from branch: chan_guan_ling
# Downloaded text file: assignment8/__init__.py from branch: chan_guan_ling
# Downloaded binary-like file: assignment8/data/AIAP_Batch 13_Technical_Assessment.pdf from branch: chan_guan_ling
# Downloaded binary-like file: assignment8/data/AIAP_Batch 14_Technical_Assessment.pdf from branch: chan_guan_ling
# Downloaded text file: assignment8/data/AIAP_Batch_13_Technical_Assessment_Results.csv from branch: chan_guan_ling
# Downloaded text file: assignment8/data/AIAP_Batch_14_Technical_Assessment_Results.csv from branch: chan_guan_ling
# Scraping complete for branch: chan_guan_ling
# Scraping branch: desmond_wong
# Directory found: assignment0
# Directory found: assignment1
# Directory found: assignment1/src
# Directory found: assignment1/tests
# Directory found: assignment2
# Directory found: assignment2/A2P1_docker_workshop
# Directory found: assignment2/imgs
# Directory found: assignment3
# Directory found: assignment3/Overview — Data Engineering Handbook for Data Engineers_files
# Directory found: assignment4
# Directory found: assignment4/src
# Directory found: assignment4/tests
# Directory found: assignment5
# Directory found: assignment5/.devcontainer
# Directory found: assignment5/data
# Directory found: assignment5/data/image
# Directory found: assignment5/images
# Directory found: assignment5/robustness_requirements
# Directory found: assignment5/src
# Directory found: assignment5/tests
# Directory found: assignment6
# Directory found: assignment6/images
# Directory found: assignment6/src
# Directory found: assignment6/tests
# Directory found: assignment7
# Directory found: assignment7/images
# Directory found: assignment7/src
# Directory found: assignment7/tests
# Directory found: assignment8
# Directory found: assignment8/data
# Directory found: ci
# Directory found: imgs
# Downloaded text file: .gitlab-ci.yml from branch: desmond_wong
# Downloaded text file: README.md from branch: desmond_wong
# Downloaded binary-like file: assignment0/A0P2_virenv_commit.ipynb from branch: desmond_wong
# Downloaded text file: assignment0/README.md from branch: desmond_wong
# Downloaded binary-like file: assignment1/A1P1_eda_extended.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment1/A1P2_intro_supervised.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment1/A1P3_rf_from_scratch.ipynb from branch: desmond_wong
# Downloaded text file: assignment1/README.md from branch: desmond_wong
# Downloaded text file: assignment1/__init__.py from branch: desmond_wong
# Downloaded text file: assignment1/requirements.txt from branch: desmond_wong
# Downloaded text file: assignment1/src/__init__.py from branch: desmond_wong
# Downloaded text file: assignment1/src/datapipeline.py from branch: desmond_wong
# Downloaded text file: assignment1/src/model.py from branch: desmond_wong
# Downloaded text file: assignment1/tests/__init__.py from branch: desmond_wong
# Downloaded text file: assignment1/tests/test_model.py from branch: desmond_wong
# Downloaded text file: assignment2/A2P1_docker_workshop/ML Ops Commandline.txt from branch: desmond_wong
# Downloaded text file: assignment2/A2P1_docker_workshop/app.py from branch: desmond_wong
# Downloaded text file: assignment2/A2P1_docker_workshop/hello.txt from branch: desmond_wong
# Downloaded text file: assignment2/A2P1_docker_workshop/requirements.txt from branch: desmond_wong
# Downloaded binary-like file: assignment2/A2_docker_overview.ipynb from branch: desmond_wong
# Downloaded text file: assignment2/README.md from branch: desmond_wong
# Downloaded binary-like file: assignment3/A3P1_load_data.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment3/A3P2_eda.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment3/A3P3_data_cleaning.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment3/A3P4_model_training.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment3/A3P5_exercise.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: desmond_wong
# Downloaded text file: assignment3/Overview — Data Engineering Handbook for Data Engineers.html from branch: desmond_wong
# Downloaded text file: assignment3/README.md from branch: desmond_wong
# Downloaded binary-like file: assignment3/kapitan-spark-slides.pdf from branch: desmond_wong
# Downloaded binary-like file: assignment3/slides-day1.pdf from branch: desmond_wong
# Downloaded binary-like file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: desmond_wong
# Downloaded binary-like file: assignment3/slides-day2.pdf from branch: desmond_wong
# Downloaded binary-like file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment4/A4P3_neural_network_scratch.ipynb from branch: desmond_wong
# Downloaded text file: assignment4/README.md from branch: desmond_wong
# Downloaded text file: assignment4/__init__.py from branch: desmond_wong
# Downloaded text file: assignment4/requirements.txt from branch: desmond_wong
# Downloaded text file: assignment4/src/__init__.py from branch: desmond_wong
# Downloaded text file: assignment4/src/datapipeline.py from branch: desmond_wong
# Downloaded text file: assignment4/src/mlp.py from branch: desmond_wong
# Downloaded text file: assignment4/src/mlp_datapipeline.py from branch: desmond_wong
# Downloaded text file: assignment4/tests/__init__.py from branch: desmond_wong
# Downloaded text file: assignment4/tests/test_mlp.py from branch: desmond_wong
# Downloaded text file: assignment5/.devcontainer/devcontainer.json from branch: desmond_wong
# Downloaded binary-like file: assignment5/A5P1_introduction.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment5/A5P2_classification.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment5/A5P3_buildCNN.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu_AppleSilicon.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment5/A5P5_robustness_testing.ipynb from branch: desmond_wong
# Downloaded text file: assignment5/README.md from branch: desmond_wong
# Downloaded text file: assignment5/__init__.py from branch: desmond_wong
# Downloaded text file: assignment5/conda.yml from branch: desmond_wong
# Downloaded text file: assignment5/requirements.txt from branch: desmond_wong
# Downloaded text file: assignment5/requirements_desmond.txt from branch: desmond_wong
# Downloaded text file: assignment5/requirements_m1.txt from branch: desmond_wong
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness.txt from branch: desmond_wong
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness_cuda.txt from branch: desmond_wong
# Downloaded text file: assignment5/src/__init__.py from branch: desmond_wong
# Downloaded text file: assignment5/src/convolved_matrices.py from branch: desmond_wong
# Downloaded text file: assignment5/src/train.py from branch: desmond_wong
# Downloaded text file: assignment5/tests/__init__.py from branch: desmond_wong
# Downloaded text file: assignment5/tests/test_convolved_matrices.py from branch: desmond_wong
# Downloaded binary-like file: assignment6/A6P1_eda_data_cleaning.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment6/A6P2_time_series_forecasting.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment6/A6P3_time_series_nn.ipynb from branch: desmond_wong
# Downloaded text file: assignment6/README.md from branch: desmond_wong
# Downloaded text file: assignment6/requirements.txt from branch: desmond_wong
# Downloaded text file: assignment6/src/cnn_model.py from branch: desmond_wong
# Downloaded text file: assignment6/src/datapipeline.py from branch: desmond_wong
# Downloaded text file: assignment6/src/eda.py from branch: desmond_wong
# Downloaded text file: assignment6/src/ml_experiment.py from branch: desmond_wong
# Downloaded text file: assignment6/src/ml_model.py from branch: desmond_wong
# Downloaded text file: assignment6/src/rnn_model.py from branch: desmond_wong
# Downloaded text file: assignment6/src/windowing.py from branch: desmond_wong
# Downloaded text file: assignment6/tests/__init__.py from branch: desmond_wong
# Downloaded binary-like file: assignment7/A7P1_nlp_introduction.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment7/A7P2_nlp_attention.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment7/A7P3_nlp_transformer.ipynb from branch: desmond_wong
# Downloaded text file: assignment7/README.md from branch: desmond_wong
# Downloaded text file: assignment7/__init__.py from branch: desmond_wong
# Downloaded text file: assignment7/src/__init__.py from branch: desmond_wong
# Downloaded text file: assignment7/src/context_vector.py from branch: desmond_wong
# Downloaded text file: assignment7/src/eda.py from branch: desmond_wong
# Downloaded text file: assignment7/tests/__init__.py from branch: desmond_wong
# Downloaded text file: assignment7/tests/test_context_vector.py from branch: desmond_wong
# Downloaded binary-like file: assignment8/A8P1_llm_introduction.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment8/A8P2_prompt_engineering.ipynb from branch: desmond_wong
# Downloaded binary-like file: assignment8/A8P3_retrieval-augmented_generation.ipynb from branch: desmond_wong
# Downloaded text file: assignment8/README.md from branch: desmond_wong
# Downloaded text file: assignment8/__init__.py from branch: desmond_wong
# Downloaded binary-like file: assignment8/data/AIAP_Batch 13_Technical_Assessment.pdf from branch: desmond_wong
# Downloaded binary-like file: assignment8/data/AIAP_Batch 14_Technical_Assessment.pdf from branch: desmond_wong
# Downloaded text file: assignment8/data/AIAP_Batch_13_Technical_Assessment_Results.csv from branch: desmond_wong
# Downloaded text file: assignment8/data/AIAP_Batch_14_Technical_Assessment_Results.csv from branch: desmond_wong
# Scraping complete for branch: desmond_wong
# Skipping branch: feature-add-new-test-cases (excluded)
# Scraping branch: hoo_chi_yang
# Directory found: assignment0
# Directory found: assignment1
# Directory found: assignment1/facets
# Directory found: assignment1/openrefine
# Directory found: assignment1/src
# Directory found: assignment1/tests
# Directory found: assignment2
# Directory found: assignment2/A2P1_docker_workshop
# Directory found: assignment2/imgs
# Directory found: assignment3
# Directory found: assignment4
# Directory found: assignment4/.gitlab
# Directory found: assignment4/.gitlab/issue_templates
# Directory found: assignment4/aisg-context
# Directory found: assignment4/aisg-context/guide-site
# Directory found: assignment4/aisg-context/guide-site/docs
# Directory found: assignment4/aisg-context/guide-site/docs/guide-for-user
# Directory found: assignment4/aisg-context/guide-site/docs/guide-for-user/assets
# Directory found: assignment4/aisg-context/guide-site/docs/guide-for-user/assets/images
# Directory found: assignment4/aisg-context/guide-site/docs/guide-for-user/assets/screenshots
# Directory found: assignment4/aisg-context/guide-site/docs/guide-for-user/assets/screenshots/external
# Directory found: assignment4/conf
# Directory found: assignment4/docker
# Directory found: assignment4/docs
# Directory found: assignment4/src
# Directory found: assignment4/src/aiap_dsp_mlops
# Directory found: assignment4/src/aiap_dsp_mlops/data_prep
# Directory found: assignment4/src/aiap_dsp_mlops/modeling
# Directory found: assignment4/src/aiap_dsp_mlops_fastapi
# Directory found: assignment4/src/aiap_dsp_mlops_fastapi/v1
# Directory found: assignment4/src/aiap_dsp_mlops_fastapi/v1/routers
# Directory found: assignment4/src/tests
# Directory found: assignment4/tests
# Directory found: assignment5
# Directory found: assignment5/conf
# Directory found: assignment5/conf/base_model
# Directory found: assignment5/data
# Directory found: assignment5/data/image
# Directory found: assignment5/diagrams
# Directory found: assignment5/docker
# Directory found: assignment5/images
# Directory found: assignment5/others
# Directory found: assignment5/requirements
# Directory found: assignment5/requirements/robustness_requirements
# Directory found: assignment5/robustness_references~ (sindy's notes)
# Directory found: assignment5/slides
# Directory found: assignment5/src
# Directory found: assignment5/src/srcpackagename
# Directory found: assignment5/src/srcpackagename/data_prep
# Directory found: assignment5/src/srcpackagename/modeling
# Directory found: assignment5/tests
# Directory found: assignment6
# Directory found: assignment6/conf
# Directory found: assignment6/images
# Directory found: assignment6/src
# Directory found: assignment6/tests
# Directory found: assignment7
# Directory found: assignment7/conf
# Directory found: assignment7/conf/model
# Directory found: assignment7/docker
# Directory found: assignment7/images
# Directory found: assignment7/src
# Directory found: assignment7/src/A7P1
# Directory found: assignment7/src/A7P3
# Directory found: assignment7/tests
# Directory found: assignment8
# Directory found: assignment8/data
# Directory found: assignment8/src
# Directory found: assignment8/src/assignment8
# Directory found: assignment8/tests
# Directory found: ci
# Directory found: imgs
# Downloaded text file: .gitlab-ci.yml from branch: hoo_chi_yang
# Downloaded text file: README.md from branch: hoo_chi_yang
# Downloaded binary-like file: assignment0/A0P2_virenv_commit.ipynb from branch: hoo_chi_yang
# Downloaded text file: assignment0/README.md from branch: hoo_chi_yang
# Downloaded binary-like file: assignment1/A1P1_eda_extended.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment1/A1P2_intro_supervised.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment1/A1P3_rf_from_scratch.ipynb from branch: hoo_chi_yang
# Downloaded text file: assignment1/README.md from branch: hoo_chi_yang
# Downloaded text file: assignment1/__init__.py from branch: hoo_chi_yang
# Downloaded text file: assignment1/conda.yml from branch: hoo_chi_yang
# Downloaded text file: assignment1/src/__init__.py from branch: hoo_chi_yang
# Downloaded text file: assignment1/src/datapipeline.py from branch: hoo_chi_yang
# Downloaded text file: assignment1/src/decision_tree.py from branch: hoo_chi_yang
# Downloaded text file: assignment1/src/model.py from branch: hoo_chi_yang
# Downloaded text file: assignment1/src/random_forest.py from branch: hoo_chi_yang
# Downloaded text file: assignment1/tests/__init__.py from branch: hoo_chi_yang
# Downloaded text file: assignment1/tests/test_model.py from branch: hoo_chi_yang
# Downloaded text file: assignment2/A2P1_docker_workshop/app.py from branch: hoo_chi_yang
# Downloaded text file: assignment2/A2P1_docker_workshop/hello.txt from branch: hoo_chi_yang
# Downloaded text file: assignment2/A2P1_docker_workshop/requirements.txt from branch: hoo_chi_yang
# Downloaded binary-like file: assignment2/A2_docker_overview.ipynb from branch: hoo_chi_yang
# Downloaded text file: assignment2/README.md from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/A3P1_load_data.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/A3P2_eda.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/A3P3_data_cleaning.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/A3P4_model_training.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/A3P5_exercise.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: hoo_chi_yang
# Downloaded text file: assignment3/README.md from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/kapitan-spark-slides.pdf from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/slides-day1.pdf from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: hoo_chi_yang
# Downloaded binary-like file: assignment3/slides-day2.pdf from branch: hoo_chi_yang
# Downloaded text file: assignment4/.gitlab-ci.yml from branch: hoo_chi_yang
# Downloaded text file: assignment4/.gitlab/issue_templates/MLOpsQueryTemplate.md from branch: hoo_chi_yang
# Downloaded binary-like file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: hoo_chi_yang
# Downloaded binary-like file: assignment4/A4P3_neural_network_scratch.ipynb from branch: hoo_chi_yang
# Downloaded text file: assignment4/README Kapitan-Hull.md from branch: hoo_chi_yang
# Downloaded text file: assignment4/README.md from branch: hoo_chi_yang
# Downloaded text file: assignment4/__init__.py from branch: hoo_chi_yang
# Downloaded text file: assignment4/aiap-dsp-mlops-conda-env.yaml from branch: hoo_chi_yang
# Downloaded text file: assignment4/aisg-context/guide-site/docs/guide-for-user/01-prerequisites.md from branch: hoo_chi_yang
# ...
# Downloaded binary-like file: assignment2/A2_docker_overview.ipynb from branch: yeo_yong_hui
# Downloaded text file: assignment2/README.md from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/A3P1_load_data.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/A3P2_eda.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/A3P3_data_cleaning.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/A3P4_model_training.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/A3P5_exercise.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: yeo_yong_hui
# Downloaded text file: assignment3/README.md from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/kapitan-spark-slides.pdf from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/slides-day1.pdf from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: yeo_yong_hui
# Downloaded binary-like file: assignment3/slides-day2.pdf from branch: yeo_yong_hui
# Downloaded binary-like file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment4/A4P3_neural_network_scratch.ipynb from branch: yeo_yong_hui
# Downloaded text file: assignment4/README.md from branch: yeo_yong_hui
# Downloaded text file: assignment4/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment4/src/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment4/src/datapipeline.py from branch: yeo_yong_hui
# Downloaded text file: assignment4/src/mlp.py from branch: yeo_yong_hui
# Downloaded text file: assignment4/src/mlp_datapipeline.py from branch: yeo_yong_hui
# Downloaded text file: assignment4/tests/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment4/tests/test_mlp.py from branch: yeo_yong_hui
# Downloaded binary-like file: assignment5/A5P1_introduction.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment5/A5P2_classification.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment5/A5P3_buildCNN.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu_AppleSilicon.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment5/A5P5_robustness_testing.ipynb from branch: yeo_yong_hui
# Downloaded text file: assignment5/README.md from branch: yeo_yong_hui
# Downloaded text file: assignment5/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment5/requirements.txt from branch: yeo_yong_hui
# Downloaded text file: assignment5/requirements_m1.txt from branch: yeo_yong_hui
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness.txt from branch: yeo_yong_hui
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness_cuda.txt from branch: yeo_yong_hui
# Downloaded text file: assignment5/src/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment5/src/convolved_matrices.py from branch: yeo_yong_hui
# Downloaded text file: assignment5/src/train.py from branch: yeo_yong_hui
# Downloaded text file: assignment5/tests/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment5/tests/test_convolved_matrices.py from branch: yeo_yong_hui
# Downloaded binary-like file: assignment6/A6P1_eda_data_cleaning.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment6/A6P2_time_series_forecasting.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment6/A6P3_time_series_nn.ipynb from branch: yeo_yong_hui
# Downloaded text file: assignment6/README.md from branch: yeo_yong_hui
# Downloaded text file: assignment6/src/cnn_model.py from branch: yeo_yong_hui
# Downloaded text file: assignment6/src/datapipeline.py from branch: yeo_yong_hui
# Downloaded text file: assignment6/src/ml_experiment.py from branch: yeo_yong_hui
# Downloaded text file: assignment6/src/ml_model.py from branch: yeo_yong_hui
# Downloaded text file: assignment6/src/rnn_model.py from branch: yeo_yong_hui
# Downloaded text file: assignment6/src/windowing.py from branch: yeo_yong_hui
# Downloaded text file: assignment6/tests/__init__.py from branch: yeo_yong_hui
# Downloaded binary-like file: assignment7/A7P1_nlp_introduction.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment7/A7P2_nlp_attention.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment7/A7P3_nlp_transformer.ipynb from branch: yeo_yong_hui
# Downloaded text file: assignment7/README.md from branch: yeo_yong_hui
# Downloaded text file: assignment7/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment7/src/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment7/src/context_vector.py from branch: yeo_yong_hui
# Downloaded text file: assignment7/tests/__init__.py from branch: yeo_yong_hui
# Downloaded text file: assignment7/tests/test_context_vector.py from branch: yeo_yong_hui
# Downloaded binary-like file: assignment8/A8P1_llm_introduction.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment8/A8P2_prompt_engineering.ipynb from branch: yeo_yong_hui
# Downloaded binary-like file: assignment8/A8P3_retrieval-augmented_generation.ipynb from branch: yeo_yong_hui
# Downloaded text file: assignment8/README.md from branch: yeo_yong_hui
# Downloaded text file: assignment8/__init__.py from branch: yeo_yong_hui
# Downloaded binary-like file: assignment8/data/AIAP_Batch 13_Technical_Assessment.pdf from branch: yeo_yong_hui
# Downloaded binary-like file: assignment8/data/AIAP_Batch 14_Technical_Assessment.pdf from branch: yeo_yong_hui
# Downloaded text file: assignment8/data/AIAP_Batch_13_Technical_Assessment_Results.csv from branch: yeo_yong_hui
# Downloaded text file: assignment8/data/AIAP_Batch_14_Technical_Assessment_Results.csv from branch: yeo_yong_hui
# Scraping complete for branch: yeo_yong_hui
# Scraping branch: zhang_zhou
# Directory found: assignment0
# Directory found: assignment1
# Directory found: assignment1/src
# Directory found: assignment1/tests
# Directory found: assignment2
# Directory found: assignment2/A2P1_docker_workshop
# Directory found: assignment2/imgs
# Directory found: assignment3
# Directory found: assignment4
# Directory found: assignment4/src
# Directory found: assignment4/tests
# Directory found: assignment5
# Directory found: assignment5/data
# Directory found: assignment5/data/image
# Directory found: assignment5/images
# Directory found: assignment5/robustness_requirements
# Directory found: assignment5/src
# Directory found: assignment5/tests
# Directory found: assignment6
# Directory found: assignment6/images
# Directory found: assignment6/src
# Directory found: assignment6/tests
# Directory found: assignment7
# Directory found: assignment7/images
# Directory found: assignment7/src
# Directory found: assignment7/tests
# Directory found: assignment8
# Directory found: assignment8/data
# Directory found: ci
# Directory found: imgs
# Downloaded text file: .gitlab-ci.yml from branch: zhang_zhou
# Downloaded text file: README.md from branch: zhang_zhou
# Downloaded binary-like file: assignment0/A0P2_virenv_commit.ipynb from branch: zhang_zhou
# Downloaded text file: assignment0/README.md from branch: zhang_zhou
# Downloaded binary-like file: assignment1/A1P1_eda_extended.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment1/A1P2_intro_supervised.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment1/A1P3_rf_from_scratch.ipynb from branch: zhang_zhou
# Downloaded text file: assignment1/README.md from branch: zhang_zhou
# Downloaded text file: assignment1/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment1/conda.yml from branch: zhang_zhou
# Downloaded text file: assignment1/src/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment1/src/datapipeline.py from branch: zhang_zhou
# Downloaded text file: assignment1/src/decision_tree.py from branch: zhang_zhou
# Downloaded text file: assignment1/src/eda_tools.py from branch: zhang_zhou
# Downloaded text file: assignment1/src/model.py from branch: zhang_zhou
# Downloaded text file: assignment1/src/random_forest.py from branch: zhang_zhou
# Downloaded text file: assignment1/tests/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment1/tests/test_model.py from branch: zhang_zhou
# Downloaded text file: assignment2/A2P1_docker_workshop/app.py from branch: zhang_zhou
# Downloaded text file: assignment2/A2P1_docker_workshop/hello.txt from branch: zhang_zhou
# Downloaded text file: assignment2/A2P1_docker_workshop/requirements.txt from branch: zhang_zhou
# Downloaded binary-like file: assignment2/A2_docker_overview.ipynb from branch: zhang_zhou
# Downloaded text file: assignment2/README.md from branch: zhang_zhou
# Downloaded binary-like file: assignment3/A3P1_load_data.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment3/A3P2_eda.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment3/A3P3_data_cleaning.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment3/A3P4_model_training.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment3/A3P5_exercise.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: zhang_zhou
# Downloaded text file: assignment3/README.md from branch: zhang_zhou
# Downloaded binary-like file: assignment3/kapitan-spark-slides.pdf from branch: zhang_zhou
# Downloaded binary-like file: assignment3/slides-day1.pdf from branch: zhang_zhou
# Downloaded binary-like file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: zhang_zhou
# Downloaded binary-like file: assignment3/slides-day2.pdf from branch: zhang_zhou
# Downloaded binary-like file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment4/A4P3_neural_network_scratch.ipynb from branch: zhang_zhou
# Downloaded text file: assignment4/README.md from branch: zhang_zhou
# Downloaded text file: assignment4/__init__.py from branch: zhang_zhou
# Downloaded binary-like file: assignment4/spotlight.ipynb from branch: zhang_zhou
# Downloaded text file: assignment4/src/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment4/src/datapipeline.py from branch: zhang_zhou
# Downloaded text file: assignment4/src/mlp.py from branch: zhang_zhou
# Downloaded text file: assignment4/src/mlp_datapipeline.py from branch: zhang_zhou
# Downloaded text file: assignment4/tests/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment4/tests/test_mlp.py from branch: zhang_zhou
# Downloaded binary-like file: assignment5/A5P1_introduction.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment5/A5P2_classification.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment5/A5P3_buildCNN.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment5/A5P4_stable_diffusion_cpu_AppleSilicon.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment5/A5P5_robustness_testing.ipynb from branch: zhang_zhou
# Downloaded text file: assignment5/README.md from branch: zhang_zhou
# Downloaded text file: assignment5/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment5/conda.yml from branch: zhang_zhou
# Downloaded text file: assignment5/requirements.txt from branch: zhang_zhou
# Downloaded text file: assignment5/requirements_m1.txt from branch: zhang_zhou
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness.txt from branch: zhang_zhou
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness_cuda.txt from branch: zhang_zhou
# Downloaded text file: assignment5/src/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment5/src/convolved_matrices.py from branch: zhang_zhou
# Downloaded text file: assignment5/src/train.py from branch: zhang_zhou
# Downloaded text file: assignment5/tests/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment5/tests/test_convolved_matrices.py from branch: zhang_zhou
# Downloaded binary-like file: assignment6/A6P1_eda_data_cleaning.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment6/A6P2_time_series_forecasting.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment6/A6P3_time_series_nn.ipynb from branch: zhang_zhou
# Downloaded text file: assignment6/README.md from branch: zhang_zhou
# Downloaded text file: assignment6/conda.yml from branch: zhang_zhou
# Downloaded text file: assignment6/requirements.txt from branch: zhang_zhou
# Downloaded text file: assignment6/src/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment6/src/cnn_model.py from branch: zhang_zhou
# Downloaded text file: assignment6/src/datapipeline.py from branch: zhang_zhou
# Downloaded text file: assignment6/src/ml_experiment.py from branch: zhang_zhou
# Downloaded text file: assignment6/src/ml_model.py from branch: zhang_zhou
# Downloaded text file: assignment6/src/rnn_model.py from branch: zhang_zhou
# Downloaded text file: assignment6/src/windowing.py from branch: zhang_zhou
# Downloaded binary-like file: assignment6/test.ipynb from branch: zhang_zhou
# Downloaded text file: assignment6/tests/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment6/tests/test_datapipeline.py from branch: zhang_zhou
# Downloaded binary-like file: assignment7/A7P1_nlp_introduction.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment7/A7P2_nlp_attention.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment7/A7P3_nlp_transformer.ipynb from branch: zhang_zhou
# Downloaded text file: assignment7/README.md from branch: zhang_zhou
# Downloaded text file: assignment7/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment7/conda.yml from branch: zhang_zhou
# Downloaded text file: assignment7/requirements.txt from branch: zhang_zhou
# Downloaded text file: assignment7/src/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment7/src/context_vector.py from branch: zhang_zhou
# Downloaded text file: assignment7/tests/__init__.py from branch: zhang_zhou
# Downloaded text file: assignment7/tests/test_context_vector.py from branch: zhang_zhou
# Downloaded binary-like file: assignment8/A8P1_llm_introduction.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment8/A8P2_prompt_engineering.ipynb from branch: zhang_zhou
# Downloaded binary-like file: assignment8/A8P3_retrieval-augmented_generation.ipynb from branch: zhang_zhou
# Downloaded text file: assignment8/README.md from branch: zhang_zhou
# Downloaded text file: assignment8/__init__.py from branch: zhang_zhou
# Downloaded binary-like file: assignment8/data/AIAP_Batch 13_Technical_Assessment.pdf from branch: zhang_zhou
# Downloaded text file: assignment8/data/AIAP_Batch 13_Technical_Assessment.txt from branch: zhang_zhou
# Downloaded binary-like file: assignment8/data/AIAP_Batch 14_Technical_Assessment.pdf from branch: zhang_zhou
# Downloaded text file: assignment8/data/AIAP_Batch 14_Technical_Assessment.txt from branch: zhang_zhou
# Downloaded text file: assignment8/data/AIAP_Batch_13_Technical_Assessment_Results.csv from branch: zhang_zhou
# Downloaded text file: assignment8/data/AIAP_Batch_14_Technical_Assessment_Results.csv from branch: zhang_zhou
# Scraping complete for branch: zhang_zhou
# Scraping complete for all branches.
