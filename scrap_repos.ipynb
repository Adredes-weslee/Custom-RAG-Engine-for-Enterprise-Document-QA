# %%
import gitlab
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get the private token from environment variables
PRIVATE_TOKEN = os.getenv("PRIVATE_TOKEN")
if not PRIVATE_TOKEN:
    raise ValueError("PRIVATE_TOKEN is not set. Please set it in the .env file.")

# Authenticate with your GitLab instance
GITLAB_URL = "https://gitlab.aisingapore.net"

# Initialize GitLab connection
gl = gitlab.Gitlab(GITLAB_URL, private_token=PRIVATE_TOKEN)

# Access the project by its ID
project_id = 2529  # Replace with your actual project ID
aiap_project = gl.projects.get(project_id)

# Specify the branch to scrape
branch_name = "soh_sze_han"  # Replace with the specific branch name you want to scrape

# Directory to store the downloaded files
DOWNLOAD_DIR = f"gitlab_branch_{branch_name}_files"
os.makedirs(DOWNLOAD_DIR, exist_ok=True)


# Function to scrape all files in a specific branch
def scrape_branch(branch_name):
    # Get repository tree (files and directories) at the root level of the branch
    tree = aiap_project.repository_tree(ref=branch_name, recursive=True, get_all=True)

    for item in tree:
        # File path to be saved
        item_path = os.path.join(DOWNLOAD_DIR, item["path"])

        if item["type"] == "blob":  # If it's a file
            # Create directories as needed
            os.makedirs(os.path.dirname(item_path), exist_ok=True)

            try:
                # Get file content from the GitLab API
                file_data = aiap_project.files.get(
                    file_path=item["path"], ref=branch_name
                )
                file_content = file_data.decode()

                # Write file content (try to handle both text and binary)
                if is_text_file(item["path"]):
                    # Handle text file
                    with open(item_path, "w", encoding="utf-8") as f:
                        f.write(file_content.decode("utf-8"))
                    print(
                        f"Downloaded text file: {item['path']} from branch: {branch_name}"
                    )
                else:
                    # Handle binary file
                    with open(item_path, "wb") as f:
                        f.write(file_content)
                    print(
                        f"Downloaded binary file: {item['path']} from branch: {branch_name}"
                    )

            except gitlab.exceptions.GitlabGetError as e:
                print(f"Failed to download file: {item['path']}. Error: {e}")

        elif item["type"] == "tree":  # If it's a directory
            # Create directory
            os.makedirs(item_path, exist_ok=True)
            print(f"Directory found: {item['path']}")


# Function to determine if a file is likely a text file based on its extension
def is_text_file(file_path):
    text_extensions = [
        ".txt",
        ".md",
        ".py",
        ".java",
        ".json",
        ".yaml",
        ".yml",
        ".csv",
        ".html",
        ".xml",
        ".sh",
    ]
    _, ext = os.path.splitext(file_path)
    return ext.lower() in text_extensions


# Scrape the specified branch
print(f"Scraping branch: {branch_name}")
scrape_branch(branch_name)
print("Scraping complete.")
# Out:
# Scraping branch: soh_sze_han
# Directory found: assignment0
# Directory found: assignment1
# Directory found: assignment1/census_data
# Directory found: assignment1/src
# Directory found: assignment1/tests
# Directory found: assignment2
# Directory found: assignment2/A2P1_docker_workshop
# Directory found: assignment2/A2P1_docker_workshop/assets
# Directory found: assignment2/imgs
# Directory found: assignment3
# Directory found: assignment4
# Directory found: assignment4/conf
# Directory found: assignment4/docker
# Directory found: assignment4/src
# Directory found: assignment4/tests
# Directory found: assignment5
# Directory found: assignment5/data
# Directory found: assignment5/data/image
# Directory found: assignment5/docker
# Directory found: assignment5/images
# Directory found: assignment5/robustness_requirements
# Directory found: assignment5/src
# Directory found: assignment5/tests
# Directory found: assignment6
# Directory found: assignment6/images
# Directory found: assignment6/src
# Directory found: assignment6/tests
# Directory found: assignment7
# Directory found: assignment7/images
# Directory found: assignment7/src
# Directory found: assignment7/tests
# Directory found: assignment8
# Directory found: assignment8/data
# Directory found: ci
# Directory found: imgs
# Downloaded binary file: .gitignore from branch: soh_sze_han
# Downloaded text file: .gitlab-ci.yml from branch: soh_sze_han
# Downloaded binary file: .pylintrc from branch: soh_sze_han
# Downloaded text file: README.md from branch: soh_sze_han
# Downloaded binary file: assignment0/.gitignore from branch: soh_sze_han
# Downloaded binary file: assignment0/A0P2_virenv_commit.ipynb from branch: soh_sze_han
# Downloaded text file: assignment0/README.md from branch: soh_sze_han
# Downloaded binary file: assignment1/A1P1_eda_extended.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment1/A1P2_intro_supervised.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment1/A1P3_rf_from_scratch.ipynb from branch: soh_sze_han
# Downloaded text file: assignment1/README.md from branch: soh_sze_han
# Downloaded text file: assignment1/__init__.py from branch: soh_sze_han
# Downloaded binary file: assignment1/census_data/Index from branch: soh_sze_han
# Downloaded binary file: assignment1/census_data/adult.data from branch: soh_sze_han
# Downloaded binary file: assignment1/census_data/adult.names from branch: soh_sze_han
# Downloaded binary file: assignment1/census_data/adult.test from branch: soh_sze_han
# Downloaded binary file: assignment1/census_data/old.adult.names from branch: soh_sze_han
# Downloaded text file: assignment1/src/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment1/src/datapipeline.py from branch: soh_sze_han
# Downloaded text file: assignment1/src/decision_tree.py from branch: soh_sze_han
# Downloaded text file: assignment1/src/model.py from branch: soh_sze_han
# Downloaded text file: assignment1/src/utils.py from branch: soh_sze_han
# Downloaded text file: assignment1/tests/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment1/tests/test_model.py from branch: soh_sze_han
# Downloaded text file: assignment1/your_report.html from branch: soh_sze_han
# Downloaded binary file: assignment2/A2P1_docker_workshop/Dockerfile from branch: soh_sze_han
# Downloaded text file: assignment2/A2P1_docker_workshop/app.py from branch: soh_sze_han
# Downloaded binary file: assignment2/A2P1_docker_workshop/assets/model.pkl from branch: soh_sze_han
# Downloaded text file: assignment2/A2P1_docker_workshop/hello.txt from branch: soh_sze_han
# Downloaded text file: assignment2/A2P1_docker_workshop/requirements.txt from branch: soh_sze_han
# Downloaded binary file: assignment2/A2_docker_overview.ipynb from branch: soh_sze_han
# Downloaded text file: assignment2/README.md from branch: soh_sze_han
# Downloaded binary file: assignment2/imgs/kapitan-hull-eptg-gcp-runai-banner.png from branch: soh_sze_han
# Downloaded binary file: assignment3/A3P1_load_data.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment3/A3P2_eda.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment3/A3P3_data_cleaning.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment3/A3P4_model_training.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment3/A3P5_exercise.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment3/A3P6_optional_pytorch_distributed.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment3/A3P7_optional_pysparkai_langchain.ipynb from branch: soh_sze_han
# Downloaded text file: assignment3/README.md from branch: soh_sze_han
# Downloaded binary file: assignment3/kapitan-spark-slides.pdf from branch: soh_sze_han
# Downloaded binary file: assignment3/slides-day1.pdf from branch: soh_sze_han
# Downloaded binary file: assignment3/slides-day2-explore-langchain-pysparkAI.pdf from branch: soh_sze_han
# Downloaded binary file: assignment3/slides-day2.pdf from branch: soh_sze_han
# Downloaded binary file: assignment4/A4P1_introduction_deep_learning.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment4/A4P2_components_of_neural_networks.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment4/A4P3_neural_network_scratch.ipynb from branch: soh_sze_han
# Downloaded text file: assignment4/README.md from branch: soh_sze_han
# Downloaded text file: assignment4/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment4/conf/logging.yaml from branch: soh_sze_han
# Downloaded text file: assignment4/conf/train_model.yaml from branch: soh_sze_han
# Downloaded binary file: assignment4/docker/aiap-dsp-mlops-cpu.Dockerfile from branch: soh_sze_han
# Downloaded binary file: assignment4/docker/aiap-dsp-mlops-gpu.Dockerfile from branch: soh_sze_han
# Downloaded text file: assignment4/pytorch-cpu-requirements.txt from branch: soh_sze_han
# Downloaded text file: assignment4/pytorch-gpu-requirements.txt from branch: soh_sze_han
# Downloaded text file: assignment4/requirements.txt from branch: soh_sze_han
# Downloaded text file: assignment4/src/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment4/src/datapipeline.py from branch: soh_sze_han
# Downloaded text file: assignment4/src/mlp.py from branch: soh_sze_han
# Downloaded text file: assignment4/src/mlp_datapipeline.py from branch: soh_sze_han
# Downloaded text file: assignment4/src/train_model.py from branch: soh_sze_han
# Downloaded text file: assignment4/tests/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment4/tests/test_mlp.py from branch: soh_sze_han
# Downloaded binary file: assignment5/A5P1_introduction.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment5/A5P2_classification.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment5/A5P3_buildCNN.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment5/A5P4_stable_diffusion_cpu.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment5/A5P4_stable_diffusion_cpu_AppleSilicon.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment5/A5P5_robustness_testing.ipynb from branch: soh_sze_han
# Downloaded text file: assignment5/README.md from branch: soh_sze_han
# Downloaded text file: assignment5/__init__.py from branch: soh_sze_han
# Downloaded binary file: assignment5/best_model.pth from branch: soh_sze_han
# Downloaded text file: assignment5/conda.yml from branch: soh_sze_han
# Downloaded binary file: assignment5/data/image/aiap_photo.jpg from branch: soh_sze_han
# Downloaded binary file: assignment5/data/image/diffusion_process.gif from branch: soh_sze_han
# Downloaded binary file: assignment5/data/image/sd_pipeline.png from branch: soh_sze_han
# Downloaded binary file: assignment5/docker/aiap-dsp-mlops-cpu.Dockerfile from branch: soh_sze_han
# Downloaded binary file: assignment5/docker/aiap-dsp-mlops-gpu.Dockerfile from branch: soh_sze_han
# Downloaded binary file: assignment5/images/cnn_parameters.png from branch: soh_sze_han
# Downloaded binary file: assignment5/images/fcl_parameters.png from branch: soh_sze_han
# Downloaded binary file: assignment5/images/fgsm_process.png from branch: soh_sze_han
# Downloaded binary file: assignment5/images/great-wall.png from branch: soh_sze_han
# Downloaded binary file: assignment5/images/tensorfood_obj_detection.jpg from branch: soh_sze_han
# Downloaded text file: assignment5/pytorch-cpu-requirements.txt from branch: soh_sze_han
# Downloaded text file: assignment5/pytorch-gpu-requirements.txt from branch: soh_sze_han
# Downloaded text file: assignment5/requirements.txt from branch: soh_sze_han
# Downloaded text file: assignment5/requirements_m1.txt from branch: soh_sze_han
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness.txt from branch: soh_sze_han
# Downloaded text file: assignment5/robustness_requirements/requirements_robustness_cuda.txt from branch: soh_sze_han
# Downloaded text file: assignment5/src/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment5/src/convolved_matrices.py from branch: soh_sze_han
# Downloaded text file: assignment5/src/train.py from branch: soh_sze_han
# Downloaded text file: assignment5/tests/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment5/tests/test_convolved_matrices.py from branch: soh_sze_han
# Downloaded binary file: assignment6/A6P1_eda_data_cleaning.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment6/A6P2_time_series_forecasting.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment6/A6P3_time_series_nn.ipynb from branch: soh_sze_han
# Downloaded text file: assignment6/README.md from branch: soh_sze_han
# Downloaded text file: assignment6/beijing_pm2_5_data.csv from branch: soh_sze_han
# Downloaded text file: assignment6/conda.yml from branch: soh_sze_han
# Downloaded binary file: assignment6/images/sin.png from branch: soh_sze_han
# Downloaded binary file: assignment6/images/window.png from branch: soh_sze_han
# Downloaded text file: assignment6/src/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment6/src/cnn_model.py from branch: soh_sze_han
# Downloaded text file: assignment6/src/datapipeline.py from branch: soh_sze_han
# Downloaded text file: assignment6/src/ml_experiment.py from branch: soh_sze_han
# Downloaded text file: assignment6/src/ml_model.py from branch: soh_sze_han
# Downloaded text file: assignment6/src/rnn_model.py from branch: soh_sze_han
# Downloaded text file: assignment6/src/windowing.py from branch: soh_sze_han
# Downloaded text file: assignment6/tests/__init__.py from branch: soh_sze_han
# Downloaded binary file: assignment7/A7P1_nlp_introduction.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment7/A7P2_nlp_attention.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment7/A7P3_nlp_transformer.ipynb from branch: soh_sze_han
# Downloaded text file: assignment7/README.md from branch: soh_sze_han
# Downloaded text file: assignment7/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment7/conda.yml from branch: soh_sze_han
# Downloaded binary file: assignment7/images/numenta_video.png from branch: soh_sze_han
# Downloaded binary file: assignment7/images/rnn_folded.png from branch: soh_sze_han
# Downloaded binary file: assignment7/images/rnn_mapping.jpeg from branch: soh_sze_han
# Downloaded binary file: assignment7/images/rnn_unfolded.png from branch: soh_sze_han
# Downloaded binary file: assignment7/images/transformer_downstream.png from branch: soh_sze_han
# Downloaded binary file: assignment7/images/xlnet_multi_label_classification.png from branch: soh_sze_han
# Failed to download file: assignment7/shap_values_explainer.npy. Error: 500: 500 Internal Server Error
# Downloaded text file: assignment7/src/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment7/src/context_vector.py from branch: soh_sze_han
# Downloaded text file: assignment7/tests/__init__.py from branch: soh_sze_han
# Downloaded text file: assignment7/tests/test_context_vector.py from branch: soh_sze_han
# Downloaded binary file: assignment8/A8P1_llm_introduction.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment8/A8P2_prompt_engineering.ipynb from branch: soh_sze_han
# Downloaded binary file: assignment8/A8P3_retrieval-augmented_generation.ipynb from branch: soh_sze_han
# Downloaded text file: assignment8/README.md from branch: soh_sze_han
# Downloaded text file: assignment8/__init__.py from branch: soh_sze_han
# Downloaded binary file: assignment8/data/AIAP_Batch 13_Technical_Assessment.pdf from branch: soh_sze_han
# Downloaded binary file: assignment8/data/AIAP_Batch 14_Technical_Assessment.pdf from branch: soh_sze_han
# Downloaded text file: assignment8/data/AIAP_Batch_13_Technical_Assessment_Results.csv from branch: soh_sze_han
# Downloaded text file: assignment8/data/AIAP_Batch_14_Technical_Assessment_Results.csv from branch: soh_sze_han
# Downloaded text file: ci/evaluate_code.sh from branch: soh_sze_han
# Downloaded binary file: imgs/AIAP-Banner.png from branch: soh_sze_han
# Downloaded binary file: imgs/AIAP-timeline.png from branch: soh_sze_han
# Scraping complete.
